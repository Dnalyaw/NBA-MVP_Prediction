# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stats = pd.read_csv("player_mvp_stats.csv")

# %%
stats
# Out:
#        Unnamed: 0          Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0               0      A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  ...
# 1               1     Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  ...
# 2               2  Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  ...
# 3               3   Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  ...
# 4               4    James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  ...
# ...           ...             ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 14087       14087   Spencer Hawes  PF   28  MIL  54   1  14.8  2.5   5.1  ...
# 14088       14088     Steve Novak  PF   33  MIL   8   0   2.8  0.3   0.9  ...
# 14089       14089  Terrence Jones  PF   25  MIL  54  12  23.5  4.3   9.1  ...
# 14090       14090      Thon Maker   C   19  MIL  57  34   9.9  1.5   3.2  ...
# 14091       14091      Tony Snell  SG   25  MIL  80  80  29.2  3.1   6.8  ...
#
# ...

# %%
pd.isnull(stats).sum()
# Out:
# Unnamed: 0       0
# Player           0
# Pos              0
# Age              0
# Tm               0
# G                0
# GS               0
# MP               0
# FG               0
# FGA              0
# FG%             50
# 3P               0
# 3PA              0
# 3P%           2042
# 2P               0
# 2PA              0
# 2P%             84
# eFG%            50
# FT               0
# FTA              0
# FT%            462
# ORB              0
# DRB              0
# TRB              0
# AST              0
# STL              0
# BLK              0
# TOV              0
# PF               0
# PTS              0
# Year             0
# Pts Won          0
# Pts Max          0
# Share            0
# Team             0
# W                0
# L                0
# W/L%             0
# GB               0
# PS/G             0
# PA/G             0
# SRS              0
# dtype: int64

# %%
stats = stats.fillna(0)

# %%
stats.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG',
#        'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT',
#        'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS', 'Year', 'Pts Won', 'Pts Max', 'Share', 'Team', 'W', 'L', 'W/L%',
#        'GB', 'PS/G', 'PA/G', 'SRS'],
#       dtype='object')

# %%
predictors = ["Age", "G", "MP", "FG", "FGA", 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'W', 'L', 'W/L%','GB', 'PS/G', 'PA/G', 'SRS']
#predictors = ["Age", "G", "MP", "FG", "FGA", 'FG%', '3P', '3PA', '3P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'W', 'L', 'W/L%']

# %%
train = stats[~(stats["Year"] == 2021)]
test = stats[stats["Year"] == 2021]

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)

# %%
reg.fit(train[predictors],train["Share"]) #Predict the share of MVP votes
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])
predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)

# %%
combination = pd.concat([test[["Player", "Share"]], predictions], axis=1)

# %%
combination.sort_values("Share", ascending=False).head(20)
# Out:
#                       Player  Share  predictions
# 641             Nikola Jokić  0.961     0.155107
# 8624             Joel Embiid  0.580     0.163590
# 3651           Stephen Curry  0.449     0.142463
# 9907   Giannis Antetokounmpo  0.345     0.206406
# 1389              Chris Paul  0.138     0.074034
# 10997            Luka Dončić  0.042     0.150263
# 7464          Damian Lillard  0.038     0.116638
# 3536           Julius Randle  0.020     0.089413
# 3531            Derrick Rose  0.010     0.035255
# 11358            Rudy Gobert  0.008     0.095305
# 3876       Russell Westbrook  0.005     0.120058
# 8616             Ben Simmons  0.003     0.064737
# 4174            James Harden  0.001     0.139850
# 5328           Kawhi Leonard  0.001     0.114246
# 3736            LeBron James  0.001     0.147377
# 9909             Jeff Teague  0.000    -0.007614
# 10672        Jalen McDaniels  0.000    -0.010576
# 10671           Grant Riller  0.000    -0.004419
# ...

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(combination["Share"], combination["predictions"])
# Out:
# 0.0026661013747447076

# %%
combination["Share"].value_counts()
# Out:
# Share
# 0.000    525
# 0.001      3
# 0.961      1
# 0.138      1
# 0.010      1
# 0.020      1
# 0.449      1
# 0.005      1
# 0.038      1
# 0.003      1
# 0.580      1
# 0.345      1
# 0.042      1
# 0.008      1
# Name: count, dtype: int64

# %%
actual = combination.sort_values("Share", ascending=False)
predicted = combination.sort_values("predictions", ascending=False)
actual["Rk"] = list(range(1,actual.shape[0]+1))
predicted["Predicted_Rk"] = list(range(1,predicted.shape[0]+1))

# %%
actual.merge(predicted, on="Player").head(5)
# Out:
#                   Player  Share_x  predictions_x  Rk  Share_y  predictions_y  \
# 0           Nikola Jokić    0.961       0.155107   1    0.961       0.155107
# 1            Joel Embiid    0.580       0.163590   2    0.580       0.163590
# 2          Stephen Curry    0.449       0.142463   3    0.449       0.142463
# 3  Giannis Antetokounmpo    0.345       0.206406   4    0.345       0.206406
# 4             Chris Paul    0.138       0.074034   5    0.138       0.074034
#
#    Predicted_Rk
# 0             3
# 1             2
# 2             6
# 3             1
# 4            33

# %%
def find_ap(combination):
    actual = combination.sort_values("Share", ascending=False).head(5)
    predicted = combination.sort_values("predictions", ascending=False)
    ps = []
    found = 0
    seen = 1
    for index,row in predicted.iterrows():
        if row["Player"] in actual["Player"].values:
            found += 1
            ps.append(found / seen)
        seen += 1

    return sum(ps) / len(ps)

# %%
find_ap(combination)
# Out:
# 0.7636363636363636

# %%
years = list(range(1991,2022))

# %%
aps = []
all_predictions = []
for year in years[5:]:
    train = stats[stats["Year"] < year]
    test = stats[stats["Year"] == year]
    reg.fit(train[predictors],train["Share"])
    predictions = reg.predict(test[predictors])
    predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)
    combination = pd.concat([test[["Player", "Share"]], predictions], axis=1)
    all_predictions.append(combination)
    aps.append(find_ap(combination))

aps
# Out:
# [0.47000000000000003,
#  0.3922012578616352,
#  0.8102564102564103,
#  0.3871428571428571,
#  0.8392857142857142,
#  0.9266666666666665,
#  0.6838935574229692,
#  0.9666666666666666,
#  0.6892857142857143,
#  0.563498817966903,
#  0.4071008403361344,
#  0.6434782608695653,
#  0.7683333333333333,
#  0.9428571428571428,
#  0.8142857142857143,
#  0.7392857142857142,
#  0.40535714285714286,
#  0.6976190476190476,
#  0.6341698841698842,
#  0.9266666666666665,
#  0.8333333333333333,
#  0.8111111111111111,
#  0.7909090909090909,
#  0.6375757575757576,
#  0.9428571428571428,
#  0.7636363636363636]

# %%
def add_ranks(predictions):
    predictions = predictions.sort_values("predictions", ascending=False)
    predictions["Predicted_Rk"] = list(range(1,predictions.shape[0]+1))
    predictions = predictions.sort_values("Share", ascending=False)
    predictions["Rk"] = list(range(1,predictions.shape[0]+1))
    predictions["Diff"] = (predictions["Rk"] - predictions["Predicted_Rk"])
    return predictions

# %%
add_ranks(all_predictions[1])
# Out:
#                 Player  Share  predictions  Predicted_Rk   Rk  Diff
# 1600       Karl Malone  0.857     0.192420             2    1    -1
# 10524   Michael Jordan  0.832     0.167740             3    2    -1
# 908         Grant Hill  0.327     0.128662             6    3    -3
# 4682      Tim Hardaway  0.207     0.060116            20    4   -16
# 8248         Glen Rice  0.117     0.033060            53    5   -48
# ...                ...    ...          ...           ...  ...   ...
# 3576     Ennis Whatley  0.000     0.010272           156  437   281
# 1138    Aaron Williams  0.000     0.010313           155  438   283
# 10136   Horacio Llamas  0.000     0.010359           154  439   285
# 10594  Kevin Salvadori  0.000     0.010653           153  440   287
# 6792     Melvin Booker  0.000    -0.055347           441  441     0
#
# [441 rows x 6 columns]

# %%
def backtest(stats, model, years, predictors):
    aps = []
    all_predictions = []
    for year in years:
        train = stats[stats["Year"] < year]
        test = stats[stats["Year"] == year]
        model.fit(train[predictors],train["Share"])
        predictions = model.predict(test[predictors])
        predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)
        combination = pd.concat([test[["Player", "Share"]], predictions], axis=1)
        combination = add_ranks(combination)
        all_predictions.append(combination)
        aps.append(find_ap(combination))
    return sum(aps) / len(aps), aps, pd.concat(all_predictions)

# %%
mean_ap, aps, all_predictions = backtest(stats, reg, years[5:], predictors)

# %%
mean_ap
# Out:
# 0.711056700356103

# %%
pd.concat([pd.Series(reg.coef_), pd.Series(predictors)], axis=1).sort_values(0, ascending=False)
# Out:
#            0     1
# 12  0.065518  eFG%
# 17  0.034361   DRB
# 27  0.028520  W/L%
# 16  0.021792   ORB
# 9   0.015905    2P
# 20  0.012053   STL
# 14  0.011502   FTA
# 21  0.011162   BLK
# 19  0.007431   AST
# 24  0.006123   PTS
# 3   0.005899    FG
# 4   0.005531   FGA
# 6   0.004898    3P
# 11  0.003112   2P%
# 0   0.000362   Age
# 28  0.000314    GB
# 25  0.000113     W
# 1   0.000095     G
# 26 -0.000309     L
# 30 -0.000326  PA/G
# 29 -0.000500  PS/G
# 31 -0.000609   SRS
# 23 -0.002355    PF
# 2  -0.004174    MP
# 15 -0.004219   FT%
# 13 -0.006925    FT
# 22 -0.009443   TOV
# 8  -0.009783   3P%
# 7  -0.011036   3PA
# 10 -0.017104   2PA
# 18 -0.027274   TRB
# 5  -0.130436   FG%

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=50, random_state=1, min_samples_split=5)

mean_ap, aps, all_predictions = backtest(stats, rf, years[28:], predictors)

# %%
mean_ap
# Out:
# 0.7868518518518518

# %%
#lets try our current year

# %%
new_predictors = ["Age", "G", "MP", "FG", "FGA", 'FG%', '3P', '3PA', '3P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'W', 'L', 'W/L%']

# %%
reg = Ridge(alpha=.1)
reg.fit(stats[new_predictors],stats["Share"]) #Predict the share of MVP votes
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[new_predictors])
predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)

# %%
combination = pd.concat([test[["Player", "Share"]], predictions], axis=1)
combination.sort_values("Share", ascending=False).head(20)
# Out:
#                       Player  Share  predictions
# 641             Nikola Jokić  0.961     0.144925
# 8624             Joel Embiid  0.580     0.164834
# 3651           Stephen Curry  0.449     0.133684
# 9907   Giannis Antetokounmpo  0.345     0.202099
# 1389              Chris Paul  0.138     0.074513
# 10997            Luka Dončić  0.042     0.141874
# 7464          Damian Lillard  0.038     0.113732
# 3536           Julius Randle  0.020     0.086416
# 3531            Derrick Rose  0.010     0.038054
# 11358            Rudy Gobert  0.008     0.097983
# 3876       Russell Westbrook  0.005     0.126090
# 8616             Ben Simmons  0.003     0.069598
# 4174            James Harden  0.001     0.137608
# 5328           Kawhi Leonard  0.001     0.112400
# 3736            LeBron James  0.001     0.136787
# 9909             Jeff Teague  0.000     0.010824
# 10672        Jalen McDaniels  0.000    -0.003313
# 10671           Grant Riller  0.000     0.000582
# ...

# %%
actual = combination.sort_values("Share", ascending=False)
predicted = combination.sort_values("predictions", ascending=False)
actual["Rk"] = list(range(1,actual.shape[0]+1))
predicted["Predicted_Rk"] = list(range(1,predicted.shape[0]+1))

# %%
actual.merge(predicted, on="Player").head(5)
# Out:
#                   Player  Share_x  predictions_x  Rk  Share_y  predictions_y  \
# 0           Nikola Jokić    0.961       0.144925   1    0.961       0.144925
# 1            Joel Embiid    0.580       0.164834   2    0.580       0.164834
# 2          Stephen Curry    0.449       0.133684   3    0.449       0.133684
# 3  Giannis Antetokounmpo    0.345       0.202099   4    0.345       0.202099
# 4             Chris Paul    0.138       0.074513   5    0.138       0.074513
#
#    Predicted_Rk
# 0             3
# 1             2
# 2             8
# 3             1
# 4            33

# %%
current_data = pd.read_csv('2025_MVP.csv').head(20).iloc[:, 1:]
current_data[['Player', 'eFG%']]
# Out:
#                      Player  eFG%
# 0   Shai Gilgeous-Alexander  63.7
# 1     Giannis Antetokounmpo  62.5
# 2              Nikola Jokić  62.7
# 3               Luka Dončić  58.7
# 4           Anthony Edwards  59.5
# 5              Jayson Tatum  58.2
# 6              Kevin Durant  64.2
# 7              Tyrese Maxey  56.2
# 8           Cade Cunningham  56.5
# 9             Jalen Brunson  60.5
# 10           Paolo Banchero  55.1
# 11             Devin Booker  58.9
# 12              LaMelo Ball  53.6
# 13           Damian Lillard  62.1
# 14            Anthony Davis  58.8
# 15             Kyrie Irving  59.4
# 16          Zion Williamson  60.0
# 17            Stephen Curry  61.8
# 18       Karl-Anthony Towns  63.0
# 19             LeBron James  60.4

# %%
current_predictions = reg.predict(current_data[new_predictors])
current_predictions = pd.DataFrame(current_predictions, columns=["predictions"])
combination_2025 = pd.concat([current_data[["Player"]], current_predictions], axis=1)

# %%
combination_2025.sort_values('predictions', ascending=False)
# Out:
#                      Player  predictions
# 12              LaMelo Ball    -2.372148
# 13           Damian Lillard    -2.420596
# 17            Stephen Curry    -2.472802
# 3               Luka Dončić    -2.529937
# 4           Anthony Edwards    -2.554981
# 5              Jayson Tatum    -2.602895
# 7              Tyrese Maxey    -2.607146
# 10           Paolo Banchero    -2.738043
# 11             Devin Booker    -2.743939
# 15             Kyrie Irving    -2.946802
# 8           Cade Cunningham    -2.961517
# 9             Jalen Brunson    -2.964958
# 0   Shai Gilgeous-Alexander    -3.096979
# 19             LeBron James    -3.231058
# 14            Anthony Davis    -3.250465
# 6              Kevin Durant    -3.260394
# 18       Karl-Anthony Towns    -3.320448
# 16          Zion Williamson    -3.700736
# 2              Nikola Jokić    -3.837958
# 1     Giannis Antetokounmpo    -3.845268

# %%
rf.fit(stats[new_predictors],stats["Share"])
# Out:
# RandomForestRegressor(min_samples_split=5, n_estimators=50, random_state=1)

# %%
curr_predictions_rf = rf.predict(current_data[new_predictors])
curr_predictions_rf = pd.DataFrame(curr_predictions_rf, columns=["predictions"])
combination_2025_rf = pd.concat([current_data[["Player"]], curr_predictions_rf], axis=1)

# %%
combination_2025_rf.sort_values('predictions', ascending=False)
# Out:
#                      Player  predictions
# 0   Shai Gilgeous-Alexander     0.908278
# 2              Nikola Jokić     0.592168
# 1     Giannis Antetokounmpo     0.436134
# 5              Jayson Tatum     0.398335
# 4           Anthony Edwards     0.315663
# 8           Cade Cunningham     0.277554
# 3               Luka Dončić     0.258894
# 18       Karl-Anthony Towns     0.189612
# 16          Zion Williamson     0.177144
# 6              Kevin Durant     0.146058
# 12              LaMelo Ball     0.134872
# 19             LeBron James     0.122896
# 17            Stephen Curry     0.100823
# 14            Anthony Davis     0.091278
# 7              Tyrese Maxey     0.082221
# 11             Devin Booker     0.078399
# 15             Kyrie Irving     0.063864
# 13           Damian Lillard     0.061011
# 9             Jalen Brunson     0.060976
# 10           Paolo Banchero     0.049274

# %%
train = stats[~(stats["Year"] == 2021)]
test = stats[stats["Year"] == 2021]

# %%
rf.fit(train[new_predictors],train["Share"])
# Out:
# RandomForestRegressor(min_samples_split=5, n_estimators=50, random_state=1)

# %%
rf_predictions = rf.predict(test[new_predictors])

# %%
final_data = test[['Player', 'Share']]

# %%
final_data['Predictions'] = rf_predictions
# Out:
# C:\Users\wayla\AppData\Local\Temp\ipykernel_59644\3153889174.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data['Predictions'] = rf_predictions

# %%
final_data.sort_values('Share', ascending = False)
# Out:
#                       Player  Share  Predictions
# 641             Nikola Jokić  0.961     0.169894
# 8624             Joel Embiid  0.580     0.466147
# 3651           Stephen Curry  0.449     0.319978
# 9907   Giannis Antetokounmpo  0.345     0.311739
# 1389              Chris Paul  0.138     0.033669
# ...                      ...    ...          ...
# 4171           Chris Chiozza  0.000     0.000000
# 4170             Bruce Brown  0.000     0.000000
# 4169           Blake Griffin  0.000     0.000000
# 4168          Andre Roberson  0.000     0.000000
# 13901             Trey Lyles  0.000     0.000000
#
# [540 rows x 3 columns]

# %%
backtest(stats, rf, [2021], predictors)
# Out:
# (0.605,
#  [0.605],
#                        Player  Share  predictions  Predicted_Rk   Rk  Diff
#  641             Nikola Jokić  0.961     0.171714            10    1    -9
#  8624             Joel Embiid  0.580     0.380319             1    2     1
#  3651           Stephen Curry  0.449     0.296658             4    3    -1
#  9907   Giannis Antetokounmpo  0.345     0.307452             3    4     1
#  1389              Chris Paul  0.138     0.029055            24    5   -19
#  ...                      ...    ...          ...           ...  ...   ...
#  8632       Terrance Ferguson  0.000     0.000000           183  536   353
#  13890           Drew Eubanks  0.000     0.000000           182  537   355
#  13889          Devin Vassell  0.000     0.000000           181  538   357
#  13888          Derrick White  0.000     0.000000           180  539   359
#  13901             Trey Lyles  0.000     0.000000           540  540     0
#
#  [540 rows x 6 columns])
